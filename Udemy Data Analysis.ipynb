# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib_inline

# %%
df=pd.read_csv(r"C:\Users\prate\Downloads\Udemy courses.csv",parse_dates=['published_timestamp'])

# %%
df.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...    True  200.0
# 1      https://www.udemy.com/goods-and-services-tax/    True   75.0
# 2  https://www.udemy.com/financial-modeling-for-b...    True   45.0
# 3  https://www.udemy.com/complete-excel-finance-c...    True   95.0
# 4  https://www.udemy.com/how-to-maximize-your-pro...    True  200.0
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0           2147.0         23.0          51.0          All Levels
# 1           2792.0        923.0         274.0          All Levels
# 2           2174.0         74.0          51.0  Intermediate Level
# 3           2451.0         11.0          36.0          All Levels
# 4           1276.0         45.0          26.0  Intermediate Level
#
#    content_duration       published_timestamp           subject
# 0               1.5 2017-01-18 20:58:58+00:00  Business Finance
# 1              39.0 2017-03-09 16:34:20+00:00  Business Finance
# 2               2.5 2016-12-19 19:26:30+00:00  Business Finance
# 3               3.0 2017-05-30 20:07:24+00:00  Business Finance
# 4               2.0 2016-12-13 14:57:18+00:00  Business Finance

# %%
df.dtypes
# Out:
# course_id                            int64
# course_title                        object
# url                                 object
# is_paid                             object
# price                              float64
# num_subscribers                    float64
# num_reviews                        float64
# num_lectures                       float64
# level                               object
# content_duration                   float64
# published_timestamp    datetime64[ns, UTC]
# subject                             object
# dtype: object

# %%
df.describe()
# Out:
#           course_id        price  num_subscribers   num_reviews  num_lectures  \
# count  3.683000e+03  3678.000000      3678.000000   3678.000000   3678.000000
# mean   6.756596e+05    66.049483      3197.150625    156.259108     40.108755
# std    3.433124e+05    61.005755      9504.117010    935.452044     50.383346
# min    8.324000e+03     0.000000         0.000000      0.000000      0.000000
# 25%    4.068710e+05    20.000000       111.000000      4.000000     15.000000
# 50%    6.876420e+05    45.000000       911.500000     18.000000     25.000000
# 75%    9.608420e+05    95.000000      2546.000000     67.000000     45.750000
# max    1.282064e+06   200.000000    268923.000000  27445.000000    779.000000
#
#        content_duration
# count       3678.000000
# mean           4.094517
# std            6.053840
# min            0.000000
# 25%            1.000000
# 50%            2.000000
# 75%            4.500000
# max           78.500000

# %%
df.shape
# Out:
# (3683, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3683 entries, 0 to 3682
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3683 non-null   int64
#  1   course_title         3683 non-null   object
#  2   url                  3678 non-null   object
#  3   is_paid              3678 non-null   object
#  4   price                3678 non-null   float64
#  5   num_subscribers      3678 non-null   float64
#  6   num_reviews          3678 non-null   float64
#  7   num_lectures         3678 non-null   float64
#  8   level                3678 non-null   object
#  9   content_duration     3678 non-null   float64
#  10  published_timestamp  3678 non-null   datetime64[ns, UTC]
#  11  subject              3678 non-null   object
# dtypes: datetime64[ns, UTC](1), float64(5), int64(1), object(5)
# memory usage: 345.4+ KB

# %% [markdown]
# # Data Cleaning

# %%
df[df.duplicated()]
# Out:
#       course_id                                       course_title  \
# 788      837322  Essentials of money value: Get a financial Life !
# 789     1157298  Introduction to Forex Trading Business For Beg...
# 895     1035638                 Understanding Financial Statements
# 1101    1084454                  CFA Level 2- Quantitative Methods
# 1474     185526                             MicroStation - C?lulas
# 2566      28295  Learn Web Designing & HTML5/CSS3 Essentials in...
#
#                                                     url is_paid  price  \
# 788    https://www.udemy.com/essentials-of-money-value/    True   20.0
# 789   https://www.udemy.com/introduction-to-forex-tr...    True   20.0
# 895   https://www.udemy.com/understanding-financial-...    True   25.0
# 1101  https://www.udemy.com/cfa-level-2-quantitative...    True   40.0
# 1474        https://www.udemy.com/microstation-celulas/    True   20.0
# 2566  https://www.udemy.com/build-beautiful-html5-we...    True   75.0
#
#       num_subscribers  num_reviews  num_lectures           level  \
# 788               0.0          0.0          20.0      All Levels
# 789               0.0          0.0          27.0  Beginner Level
# 895               0.0          0.0          10.0      All Levels
# 1101              0.0          0.0          35.0      All Levels
# 1474              0.0          0.0           9.0  Beginner Level
# 2566          43285.0        525.0          24.0      All Levels
#
#       content_duration       published_timestamp           subject
# 788           0.616667 2016-05-16 18:28:30+00:00  Business Finance
# 789           1.500000 2017-04-23 16:19:01+00:00  Business Finance
# 895           1.000000 2016-12-15 14:56:17+00:00  Business Finance
# 1101          5.500000 2017-07-02 14:29:35+00:00  Business Finance
# 1474          0.616667 2014-04-15 21:48:55+00:00    Graphic Design
# 2566          4.000000 2013-01-03 00:55:31+00:00   Web Development

# %%
df=df.drop_duplicates()

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [course_id, course_title, url, is_paid, price, num_subscribers, num_reviews, num_lectures, level, content_duration, published_timestamp, subject]
# Index: []

# %%
df.isnull().sum()
# Out:
# course_id              0
# course_title           0
# url                    5
# is_paid                5
# price                  5
# num_subscribers        5
# num_reviews            5
# num_lectures           5
# level                  5
# content_duration       5
# published_timestamp    5
# subject                5
# dtype: int64

# %%
# visualising null values

sns.heatmap(df.isnull())

# nan values would be then a lighter color would have been appeared for it
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
#total number of courses
df.groupby('subject')['course_title'].count()
# Out:
# subject
# Business Finance       1191
# Graphic Design          602
# Musical Instruments     680
# Web Development        1199
# Name: course_title, dtype: int64

# %%
df['subject'].value_counts()
# Out:
# Web Development        1199
# Business Finance       1191
# Musical Instruments     680
# Graphic Design          602
# Name: subject, dtype: int64

# %%
plt.figure(figsize=(8,8))
sns.countplot(x='subject',data=df)

plt.xlabel("subjects")
plt.ylabel("no. of courses per subject")
# Out:
# Text(0, 0.5, 'no. of courses per subject')

# %%
# no of courses udemy provides for each level
sns.countplot(x='level',data=df)
plt.ylabel("no of courses at each level")
# Out:
# Text(0, 0.5, 'no of courses at each level')

# %%
df['level'].value_counts()
# Out:
# All Levels            1925
# Beginner Level        1268
# Intermediate Level     421
# Expert Level            58
# Name: level, dtype: int64

# %%
slices=df['level'].value_counts()

plt.pie(slices)
plt.show()

# %%
df['is_paid'].value_counts()
# Out:
# True     3362
# False     310
# Name: is_paid, dtype: int64

# %%
sns.countplot(x='is_paid',data=df)

plt.ylabel("no.of courses")
plt.xlabel("paid & free courses")
# Out:
# Text(0.5, 0, 'paid & free courses')

# %%
df.groupby('is_paid')['num_lectures'].sum()
# Out:
# is_paid
# False      6639.0
# True     140756.0
# Name: num_lectures, dtype: float64

# %%
sns.barplot(y='num_lectures', x='level' ,data=df,hue='is_paid')
# Out:
# <AxesSubplot:xlabel='level', ylabel='num_lectures'>

# %%
sns.barplot(x='is_paid',y='num_lectures',data=df)
# Out:
# <AxesSubplot:xlabel='is_paid', ylabel='num_lectures'>

# %%
df.groupby('is_paid')['num_subscribers'].sum().sort_values(ascending=False)
# Out:
# is_paid
# True     8140310.0
# False    3575525.0
# Name: num_subscribers, dtype: float64

# %%
sns.barplot(x='is_paid',y='num_subscribers',data=df)
# Out:
# <AxesSubplot:xlabel='is_paid', ylabel='num_subscribers'>

# %%
# Level which has highest number of subscribers
df.groupby('level')['num_subscribers'].sum().sort_values(ascending=False)
# Out:
# level
# All Levels            6871791.0
# Beginner Level        4051843.0
# Intermediate Level     742005.0
# Expert Level            50196.0
# Name: num_subscribers, dtype: float64

# %%
plt.figure(figsize=(10,10))
sns.barplot(x='level',y='num_subscribers',data=df)
# Out:
# <AxesSubplot:xlabel='level', ylabel='num_subscribers'>
